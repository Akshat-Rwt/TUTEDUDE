# %%
pip install openpyxl --upgrade
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd 
path = "D:/TuteDude/Data Analysis/Data.xlsx"
df= pd.read_excel(path)
print(df)
# Out:
#     S.No     A   B   C     D   E  Length
# 0      1   2.0   1   5   3.0   4      45
# 1      2   4.0   3  10   6.0   8      43
# 2      3   6.0   5  15   9.0  12      66
# 3      4   8.0   7  20  12.0  16      78
# 4      5  10.0   9  25  15.0  20      32
# 5      6  12.0  11  30  18.0  24      12
# 6      7  14.0  13  35  21.0  28      54
# 7      8  16.0  15  40  24.0  32      67
# 8      9  18.0  17  45  27.0  36      77
# 9     10  20.0  19  50  30.0  40      89
# 10    11   NaN  21  55   NaN  44      45

# %%
df.head(5)
# Out:
#    S.No     A  B   C     D   E  Length
# 0     1   2.0  1   5   3.0   4    45.0
# 1     2   4.0  3  10   6.0   8    43.0
# 2     3   6.0  5  15   9.0  12    66.0
# 3     4   8.0  7  20  12.0  16    78.0
# 4     5  10.0  9  25  15.0  20    32.0

# %% [markdown]
# # Change Header

# %%
headers = ["S.NO","Even","Odd","Multiples 5 " , "Multiples 3" , "Multiples 4"]
df.columns = headers
df.head(5)
# Out:
#    S.NO  Even  Odd  Multiples 5   Multiples 3  Multiples 4
# 0     1   2.0    1             5          3.0            4
# 1     2   4.0    3            10          6.0            8
# 2     3   6.0    5            15          9.0           12
# 3     4   8.0    7            20         12.0           16
# 4     5  10.0    9            25         15.0           20

# %% [markdown]
# # Add 1 in Odd number

# %%
df["Odd"] = df["Odd"]+1

# %%
df.head()
# Out:
#    S.NO  Even  Odd  Multiples 5   Multiples 3  Multiples 4
# 0     1     2    2             5            3            4
# 1     2     4    4            10            6            8
# 2     3     6    6            15            9           12
# 3     4     8    8            20           12           16
# 4     5    10   10            25           15           20

# %%
df["Odd"] = df["Odd"]+1

# %%
df.head()
# Out:
#    S.NO  Even  Odd  Multiples 5   Multiples 3  Multiples 4
# 0     1     2    1             5            3            4
# 1     2     4    3            10            6            8
# 2     3     6    5            15            9           12
# 3     4     8    7            20           12           16
# 4     5    10    9            25           15           20

# %%
print(df)
# Out:
#    S.NO  Even  Odd  Multiples 5   Multiples 3  Multiples 4
# 0     1     2    1             5            3            4
# 1     2     4    3            10            6            8
# 2     3     6    5            15            9           12
# 3     4     8    7            20           12           16
# 4     5    10    9            25           15           20
# 5     6    12   11            30           18           24
# 6     7    14   13            35           21           28
# 7     8    16   15            40           24           32
# 8     9    18   17            45           27           36
# 9    10    20   19            50           30           40

# %%
print(df)
# Out:
#     S.NO  Even  Odd  Multiples 5   Multiples 3  Multiples 4
# 0      1   2.0    1             5          3.0            4
# 1      2   4.0    3            10          6.0            8
# 2      3   6.0    5            15          9.0           12
# 3      4   8.0    7            20         12.0           16
# 4      5  10.0    9            25         15.0           20
# 5      6  12.0   11            30         18.0           24
# 6      7  14.0   13            35         21.0           28
# 7      8  16.0   15            40         24.0           32
# 8      9  18.0   17            45         27.0           36
# 9     10  20.0   19            50         30.0           40
# 10    11   NaN   21            55          NaN           44

# %% [markdown]
# # I Donot want Last Row

# %%
# df.dropna(subset = ["Even"] , axis = 0 )

# %% [markdown]
# # How to Change the Value in NAN

# %%
import numpy as np
df["Even"].replace(np.nan, 22)
# Out:
# 0      2.0
# 1      4.0
# 2      6.0
# 3      8.0
# 4     10.0
# 5     12.0
# 6     14.0
# 7     16.0
# 8     18.0
# 9     20.0
# 10    22.0
# Name: Even, dtype: float64

# %% [markdown]
# # Change Multiple of 4 Into Multiple of 2

# %%
df["Multiples 4"] = df["Multiples 4"] / 2

# %%
df.head(5)
# Out:
#    S.NO  Even  Odd  Multiples 5   Multiples 3  Multiples 4
# 0     1   2.0    1             5          3.0          2.0
# 1     2   4.0    3            10          6.0          4.0
# 2     3   6.0    5            15          9.0          6.0
# 3     4   8.0    7            20         12.0          8.0
# 4     5  10.0    9            25         15.0         10.0

# %%
df.rename(columns = {"Multiples 4":"Mupltiples 2"})
# Out:
#     S.NO  Even  Odd  Multiples 5   Multiples 3  Mupltiples 2
# 0      1   2.0    1             5          3.0           2.0
# 1      2   4.0    3            10          6.0           4.0
# 2      3   6.0    5            15          9.0           6.0
# 3      4   8.0    7            20         12.0           8.0
# 4      5  10.0    9            25         15.0          10.0
# 5      6  12.0   11            30         18.0          12.0
# 6      7  14.0   13            35         21.0          14.0
# 7      8  16.0   15            40         24.0          16.0
# 8      9  18.0   17            45         27.0          18.0
# 9     10  20.0   19            50         30.0          20.0
# 10    11   NaN   21            55          NaN          22.0

# %%
df.dtypes
# Out:
# S.NO              int64
# Even            float64
# Odd               int64
# Multiples 5       int64
# Multiples 3     float64
# Multiples 4     float64
# dtype: object

# %%
df.drop([10],axis=0)
# Out:
#    S.NO  Even  Odd  Multiples 5   Multiples 3  Multiples 4
# 0     1   2.0    1             5          3.0          2.0
# 1     2   4.0    3            10          6.0          4.0
# 2     3   6.0    5            15          9.0          6.0
# 3     4   8.0    7            20         12.0          8.0
# 4     5  10.0    9            25         15.0         10.0
# 5     6  12.0   11            30         18.0         12.0
# 6     7  14.0   13            35         21.0         14.0
# 7     8  16.0   15            40         24.0         16.0
# 8     9  18.0   17            45         27.0         18.0
# 9    10  20.0   19            50         30.0         20.0

# %%
df.rename(columns = {"Multiples 4":"Multiples 2"} , inplace = True)

# %%
print(df)
# Out:
#     S.NO  Even  Odd  Multiples 5   Multiples 3  Multiples 2
# 0      1   2.0    1             5          3.0          2.0
# 1      2   4.0    3            10          6.0          4.0
# 2      3   6.0    5            15          9.0          6.0
# 3      4   8.0    7            20         12.0          8.0
# 4      5  10.0    9            25         15.0         10.0
# 5      6  12.0   11            30         18.0         12.0
# 6      7  14.0   13            35         21.0         14.0
# 7      8  16.0   15            40         24.0         16.0
# 8      9  18.0   17            45         27.0         18.0
# 9     10  20.0   19            50         30.0         20.0
# 10    11   NaN   21            55          NaN         22.0

# %%
df.dtypes
# Out:
# S.NO              int64
# Even            float64
# Odd               int64
# Multiples 5       int64
# Multiples 3     float64
# Multiples 2     float64
# dtype: object

# %% [markdown]
# # Convert Float 64 into int 64

# %%
df["Multiples 2"] = df["Multiples 2"].astype("int")

# %%
print(df)
# Out:
#     S.NO  Even  Odd  Multiples 5   Multiples 3  Multiples 2
# 0      1   2.0    1             5          3.0            2
# 1      2   4.0    3            10          6.0            4
# 2      3   6.0    5            15          9.0            6
# 3      4   8.0    7            20         12.0            8
# 4      5  10.0    9            25         15.0           10
# 5      6  12.0   11            30         18.0           12
# 6      7  14.0   13            35         21.0           14
# 7      8  16.0   15            40         24.0           16
# 8      9  18.0   17            45         27.0           18
# 9     10  20.0   19            50         30.0           20
# 10    11   NaN   21            55          NaN           22

# %% [markdown]
# # Data Normalization

# %%
# Simple Feacture Scaling Method

# %%
# df["Lenght"] = df["Length"]/df["Length"].max()

# %%
df.head(5)
# Out:
#    S.No     A  B   C     D   E  Length
# 0     1   2.0  1   5   3.0   4    45.0
# 1     2   4.0  3  10   6.0   8    43.0
# 2     3   6.0  5  15   9.0  12    66.0
# 3     4   8.0  7  20  12.0  16    78.0
# 4     5  10.0  9  25  15.0  20    32.0

# %%
# Min - Max Method
#df["Length"] = (df["Length"] - df["Length"].min())/(df["Length"].max() - df["Length"].min())

# %%
df.head()
# Out:
#    S.No     A  B   C     D   E  Length
# 0     1   2.0  1   5   3.0   4    45.0
# 1     2   4.0  3  10   6.0   8    43.0
# 2     3   6.0  5  15   9.0  12    66.0
# 3     4   8.0  7  20  12.0  16    78.0
# 4     5  10.0  9  25  15.0  20    32.0

# %%
# Z -Score Method
df["Length"] = (df["Length"] - df["Length"].mean())/df["Length"].std()

# %%
df.head()
# Out:
#    S.No     A  B   C     D   E    Length
# 0     1   2.0  1   5   3.0   4 -0.477507
# 1     2   4.0  3  10   6.0   8 -0.562022
# 2     3   6.0  5  15   9.0  12  0.409896
# 3     4   8.0  7  20  12.0  16  0.916983
# 4     5  10.0  9  25  15.0  20 -1.026852

# %% [markdown]
# # Convert Numeric To Categorical

# %%
import numpy as np 
bins = np.linspace(min(df["Length"]), max(df["Length"]),4)

# %%
group_names = ["Low","Medium","High"]

# %%
df["Length-binned"] = pd.cut(df["Length"],bins,labels = group_names,include_lowest = True )

# %%
df.head()
# Out:
#    S.No     A  B   C     D   E  Length Length-binned
# 0     1   2.0  1   5   3.0   4    45.0        Medium
# 1     2   4.0  3  10   6.0   8    43.0        Medium
# 2     3   6.0  5  15   9.0  12    66.0          High
# 3     4   8.0  7  20  12.0  16    78.0          High
# 4     5  10.0  9  25  15.0  20    32.0           Low

# %%
# Convert Categorical Data into Numeric

# %%
df.head()
# Out:
#    S.No     A  B   C     D   E  Length
# 0     1   2.0  1   5   3.0   4    45.0
# 1     2   4.0  3  10   6.0   8    43.0
# 2     3   6.0  5  15   9.0  12    66.0
# 3     4   8.0  7  20  12.0  16    78.0
# 4     5  10.0  9  25  15.0  20    32.0

# %%
pd.get_dummies(df["Length"])
# Out:
#      12.0   32.0   43.0   45.0   54.0   66.0   67.0   77.0   78.0   89.0
# 0   False  False  False   True  False  False  False  False  False  False
# 1   False  False   True  False  False  False  False  False  False  False
# 2   False  False  False  False  False   True  False  False  False  False
# 3   False  False  False  False  False  False  False  False   True  False
# 4   False   True  False  False  False  False  False  False  False  False
# 5    True  False  False  False  False  False  False  False  False  False
# 6   False  False  False  False   True  False  False  False  False  False
# 7   False  False  False  False  False  False   True  False  False  False
# 8   False  False  False  False  False  False  False   True  False  False
# 9   False  False  False  False  False  False  False  False  False   True
# 10  False  False  False  False  False  False  False  False  False  False

# %%
df.describe()
# Out:
#             S.No          A         B          C          D          E  \
# count  11.000000  10.000000  11.00000  11.000000  10.000000  11.000000
# mean    6.000000  11.000000  11.00000  30.000000  16.500000  24.000000
# std     3.316625   6.055301   6.63325  16.583124   9.082951  13.266499
# min     1.000000   2.000000   1.00000   5.000000   3.000000   4.000000
# 25%     3.500000   6.500000   6.00000  17.500000   9.750000  14.000000
# 50%     6.000000  11.000000  11.00000  30.000000  16.500000  24.000000
# 75%     8.500000  15.500000  16.00000  42.500000  23.250000  34.000000
# max    11.000000  20.000000  21.00000  55.000000  30.000000  44.000000
#
#           Length
# count  10.000000
# mean   56.300000
# std    23.664554
# min    12.000000
# 25%    43.500000
# 50%    60.000000
# 75%    74.500000
# max    89.000000

# %%
df.head()
# Out:
#    S.No     A  B   C     D   E  Length
# 0     1   2.0  1   5   3.0   4    45.0
# 1     2   4.0  3  10   6.0   8    43.0
# 2     3   6.0  5  15   9.0  12    66.0
# 3     4   8.0  7  20  12.0  16    78.0
# 4     5  10.0  9  25  15.0  20    32.0

# %% [markdown]
# # Value Count

# %%
index = pd.Index(df["Length"])

# %%
index.value_counts()
# Out:
# Length
# 45    2
# 43    1
# 66    1
# 78    1
# 32    1
# 12    1
# 54    1
# 67    1
# 77    1
# 89    1
# Name: count, dtype: int64

# %% [markdown]
# # BoxPLot And ScatterPLot

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.1.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
 pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (24.3.1)
# Collecting pip
#   Using cached pip-25.0-py3-none-any.whl.metadata (3.7 kB)
# Using cached pip-25.0-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.3.1
#     Uninstalling pip-24.3.1:
#       Successfully uninstalled pip-24.3.1
# Successfully installed pip-25.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Box Plot 
import seaborn as sns
sns.boxplot(x = "Length" , y = "E" , data = df)
# Out:
# <Axes: xlabel='Length', ylabel='E'>

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\aksha\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Scatter PLot 
import matplotlib.pyplot as plt
x = df["Length"]
y = df["E"]

plt.scatter(x,y)
plt.title("ScatterPlot along the x and y axis ")

plt.xlabel("Lenght")
plt.ylabel("Width")
# Out:
# Text(0, 0.5, 'Width')

# %% [markdown]
# # GroupBy

# %%
import numpy as np
grp = df.groupby("A")
grp.aggregate(np.sum)
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_10540\1725624464.py:3: FutureWarning: The provided callable <function sum at 0x00000226ABC4D6C0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grp.aggregate(np.sum)
#       S.No   B   C     D   E  Length
# A
# 2.0      1   1   5   3.0   4      45
# 4.0      2   3  10   6.0   8      43
# 6.0      3   5  15   9.0  12      66
# 8.0      4   7  20  12.0  16      78
# 10.0     5   9  25  15.0  20      32
# 12.0     6  11  30  18.0  24      12
# 14.0     7  13  35  21.0  28      54
# 16.0     8  15  40  24.0  32      67
# 18.0     9  17  45  27.0  36      77
# 20.0    10  19  50  30.0  40      89

# %%
grp = df.groupby(["A","B"])
grp.aggregate(np.sum)
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_10540\739679200.py:2: FutureWarning: The provided callable <function sum at 0x00000226ABC4D6C0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grp.aggregate(np.sum)
#          S.No   C     D   E  Length
# A    B
# 2.0  1      1   5   3.0   4      45
# 4.0  3      2  10   6.0   8      43
# 6.0  5      3  15   9.0  12      66
# 8.0  7      4  20  12.0  16      78
# 10.0 9      5  25  15.0  20      32
# 12.0 11     6  30  18.0  24      12
# 14.0 13     7  35  21.0  28      54
# 16.0 15     8  40  24.0  32      67
# 18.0 17     9  45  27.0  36      77
# 20.0 19    10  50  30.0  40      89

# %% [markdown]
# # By this the space are adjusted

# %%
grp = df.groupby(["A","B"], as_index = False)
grp.aggregate(np.sum)
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_10540\1669458045.py:2: FutureWarning: The provided callable <function sum at 0x00000226ABC4D6C0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grp.aggregate(np.sum)
#       A   B  S.No   C     D   E  Length
# 0   2.0   1     1   5   3.0   4      45
# 1   4.0   3     2  10   6.0   8      43
# 2   6.0   5     3  15   9.0  12      66
# 3   8.0   7     4  20  12.0  16      78
# 4  10.0   9     5  25  15.0  20      32
# 5  12.0  11     6  30  18.0  24      12
# 6  14.0  13     7  35  21.0  28      54
# 7  16.0  15     8  40  24.0  32      67
# 8  18.0  17     9  45  27.0  36      77
# 9  20.0  19    10  50  30.0  40      89

# %%
grp.size()
# Out:
#       A   B  size
# 0   2.0   1     1
# 1   4.0   3     1
# 2   6.0   5     1
# 3   8.0   7     1
# 4  10.0   9     1
# 5  12.0  11     1
# 6  14.0  13     1
# 7  16.0  15     1
# 8  18.0  17     1
# 9  20.0  19     1

# %%
grp.count()
# Out:
#       A   B  S.No  C  D  E  Length
# 0   2.0   1     1  1  1  1       1
# 1   4.0   3     1  1  1  1       1
# 2   6.0   5     1  1  1  1       1
# 3   8.0   7     1  1  1  1       1
# 4  10.0   9     1  1  1  1       1
# 5  12.0  11     1  1  1  1       1
# 6  14.0  13     1  1  1  1       1
# 7  16.0  15     1  1  1  1       1
# 8  18.0  17     1  1  1  1       1
# 9  20.0  19     1  1  1  1       1

# %%
l = [["apple",1],["apple",2],["aaple",2],["ball",1],["ball",1]]
df_10 = pd.DataFrame(l , columns = ["A", "B"])
print(df_10)
# Out:
#        A  B
# 0  apple  1
# 1  apple  2
# 2  aaple  2
# 3   ball  1
# 4   ball  1

# %%
df_10.groupby("A")["B"].nunique()
# Out:
# A
# aaple    1
# apple    2
# ball     1
# Name: B, dtype: int64
